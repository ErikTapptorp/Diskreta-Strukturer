# %% [markdown]
# # Assignment 8: Combinatorics
#
# *If something in the reading assignment is unclear or does not make sense, make a note and ask the lecturer, a TA in the exercise session, or a friend!*
#
#
# ### Homework Exercises
#
# Solutions to the following exercises are to be handed in, either typed or handwritten. Write neatly and concisely, so the solutions are easy to read. You are allowed (even encouraged) to work in groups, but solutions have to be written and handed in individually. If you worked in groups, please state on your answer sheet who you worked with.
#
# 1. (MIT 15.35) Questions (a)-(g) below all have one of expressions 1-8 as their answer. Assign an answer to each question and briefly motivate your choice.
#     Expressions:
#     1. $\frac{n!}{(n-m)!}$
#
#     2. $\binom{n+m}{m}$
#
#     3. $(n-m)!$
#
#     4. $m^n$
#
#     5. $\binom{n-1+m}{m}$
#
#     6. $\binom{n-1+m}{n}$
#
#     7. $2^{mn}$
#
#     8. $n^m$
#
#     Questions:
#
#     (a) How many length-$m$ words can be formed from an $n$-letter alphabet if every letter can be used at most once?
#
#     (b) How many length-$m$ words can be formed from an $n$-letter alphabet if letters can be reused?
#
#     (c) How many binary relations are there from a set $A$ to a set $B$ when $\lvert A \rvert = m$ and $\lvert B \rvert = n$?
#
#     (d) How many total injective functions are there from a set $A$ to a set $B$ when $\lvert A \rvert = m$ and $\lvert B \rvert = n \geq m$?
#
#     (e) How many ways are there to place a total of $m$ distinguishable balls into $n$ distinguishable urns, if urns are allowed to be empty or contain several balls?
#
#     (f) How many ways are there to place a total of $m$ indistinguishable balls into $n$ distinguishable urns, if urns are allowed to be empty or contain several balls?
#
#     (g) How many ways are there to place a total of $m$ distinguishable balls into $n$ distinguishable urns, with at most one ball in each urn?
#
#
#
# 2. (MIT 15.38) Below is a list of properties that a group of people might possess. For each, either state the minimum number of people that must be in a group to ensure that the property holds, or indicate that the property need not hold even for arbitrarily large groups of people. Assume that a year has 365 days.
#
#     (a) At least two people were born on the same day of the year.
#
#     (b) At least two people were born on January 1st.
#
#     (c) At least $3$ people were born on the same day of the week.
#
#     (d) At least $4$ people were born in the same month.
#
#     (e) At least $2$ people were born exactly one week apart.
#
# 3. How many integers between 1 and 3000 are divisible by at least one of $3, 5$, or $7$?
#
# 4. Find a closed-form expression involving only $n$ for the expression $\sum_{k = 0}^n 2^k \binom{n}{k}$.

# %% [markdown]
# ### Programming Exercise
#
# In this assignment you will use combinatorics to explore the *birthday paradox*, which is the following counterintuitive fact: If we suppose that it is equally likely to be born on any day of the year, then there is a roughly 50% chance that in a room with $23$ people, at least two of them have the same birthday.
#
# **Task 1:** Investigate whether this is actually true by running a Python program that uniformly picks an integer in the range (1, 365) until a previously picked number is picked again. Do so 100 times, and look at the results. Report the fraction of your results where there were more than 23 draws. The `random` package and `random.randint()` function might be helpful for this assignment.

# %%
import random
import statistics


def birthday_trial():
    return

# %% [markdown]
# **Task 2:** Find an expression for the probability of $m$ people all having different birthdays if each birthday is equally likely (most likely, it will involve $\prod$ notation). What is the value for $m = 23$? You are allowed to use a computer to calculate this probability.

# %%
# calculate the probability here

# %% [markdown]
# **Task 3:** What is the probability that everyone in a room of $m$ people has the same birthday as you do? How does that compare to the probability in the birthday paradox?

# %% [markdown]
# **Task 4:** For $k \in \{3, 4, 5\}$, modify the code in **Task 1** to estimate the number of people needed in a room for there to be a 50% chance that at least $k$ people have the same birthday. Compare your results with the entries in [this page.](https://oeis.org/A014088)

# %%
# calculations here
